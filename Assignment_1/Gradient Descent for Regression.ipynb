# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
# Data reading
data = np.loadtxt("Datasets/Dataset_2_train.csv", delimiter=",",dtype = float , usecols=(0, 1))
data_V = np.loadtxt("Datasets/Dataset_2_valid.csv", delimiter=",",dtype = float , usecols=(0, 1))
data_T = np.loadtxt("Datasets/Dataset_2_valid.csv", delimiter=",",dtype = float , usecols=(0, 1))

# %%
data.shape
# Out:
# (300, 2)

# %%
data_X = data[:, 0]
data_Y = data[:, 1]
data_V_X = data_V[:, 0]
data_V_Y = data_V[:, 1]
data_T_X = data_T[:, 0]
data_T_Y = data_T[:, 1]

# %%
plt.scatter(data_X, data_Y)
plt.plot()
# Out:
# []

# %%
def stochastic_gradient_descent(X, y_true, epochs, learning_rate ):
 
    w = 0 
    b = 0
    total_samples = len(X)
    
    cost_list = []
    epoch_list = []
#     index = np.arange(0,total_samples)
    for i in range(epochs):
        random_index = random.sample(range(total_samples), total_samples-1 ) # liste des index en ordre aleatoire np.random.choice
        cost_epoch = 0
        for j in random_index:
             
        
             sample_x = X[j]
             sample_y = y_true[j]

             y_predicted = sample_x*w + b


             w_grad = -(2/total_samples) * (sample_x*(sample_y-y_predicted))
             b_grad = -(2/total_samples) * (sample_y-y_predicted)

             w = w - learning_rate * w_grad
             b = b - learning_rate * b_grad

             cost_epoch += np.square(sample_y-y_predicted)

        cost_list.append(cost_epoch/len(random_index))
        epoch_list.append(i)
        
        if(i != 0 and np.abs(cost_list[-1] - cost_list[-2]) < 5e-6 ):
           print(i)
           
        
    return w, b, cost_list, epoch_list

# w_sgd, b_sgd, cost_sgd, cost_list_sgd, epoch_list_sgd = SGD(data_X,data_Y.reshape(scaled_y.shape[0],),10000)
# w_sgd, b_sgd, cost_sgd

# %%
w_sgd, b_sgd, cost_list_sgd, epoch_list_sgd = stochastic_gradient_descent(data_V_X, data_V_Y, 15000, 1e-4)
w_sgd, b_sgd,
# Out:
# 7168
# 7282
# 7310
# 8153
# 9180
# 9625
# 9867
# 9960
# 9966
# 10216
# 10233
# 10876
# 11079
# 11315
# 11381
# 11630
# 11631
# 11953
# 12183
# 12204
# 12250
# 12578
# 12652
# 12852
# 13041
# 13487
# 13671
# 14196
# 14394
# 14412
# 14677
# 14771
# (3.824741693384385, 3.9619791215091245)

# %% [markdown]
# # Question 1.a) RMSE Validation

# %%
print("RMSE de validation est: ", cost_list_sgd[-1])
# Out:
# RMSE de validation est:  0.14453089995915647

# %% [markdown]
# # #Question 1.a) Plot Validation RMSE VS epoch

# %%
plt.xlabel("epoch")
plt.ylabel("RMSE")
plt.plot(epoch_list_sgd,cost_list_sgd, label = "Validation RMSE")
plt.legend()

# %%
w_sgdT, b_sgdT, cost_list_sgdT, epoch_list_sgdT = stochastic_gradient_descent(data_T_X, data_T_Y, 15000, 1e-2)
w_sgdT, b_sgdT,
# Out:
# 440
# 651
# 681
# 774
# 788
# 879
# 904
# 907
# 983
# 1091
# 1149
# 1150
# 1249
# 1267
# 1365
# 1381
# 1404
# 1430
# 1439
# 1540
# 1572
# 1588
# 1602
# 1643
# 1674
# 1787
# 1819
# 1860
# 2034
# 2063
# 2213
# 2227
# 2393
# 2434
# 2523
# 2712
# 2754
# 2835
# 2848
# 2858
# 2876
# 2905
# 2907
# 2945
# 2946
# 2951
# 2983
# 2984
# 2988
# 3086
# 3195
# 3210
# 3243
# 3289
# 3346
# 3355
# 3382
# 3437
# 3449
# 3453
# 3489
# 3499
# 3557
# 3604
# 3609
# 3618
# 3674
# 3738
# 3787
# 3806
# 3882
# 3901
# 3906
# 3930
# 3996
# 4008
# 4038
# 4147
# 4209
# 4247
# 4330
# 4361
# 4403
# 4461
# 4490
# 4491
# 4525
# 4527
# 4541
# 4579
# 4581
# 4619
# 4640
# 4646
# 4694
# 4717
# 4742
# 4768
# 4928
# 5056
# 5095
# 5104
# 5139
# 5176
# 5183
# 5314
# 5326
# 5376
# 5397
# 5407
# 5408
# 5433
# 5435
# 5526
# 5613
# 5695
# 5755
# 5793
# 5809
# 5830
# 5835
# 5839
# 5875
# 5889
# 6019
# 6066
# 6146
# 6267
# 6289
# 6351
# 6366
# 6397
# 6403
# 6439
# 6450
# 6499
# 6551
# 6561
# 6572
# 6710
# 6725
# 6773
# 6836
# 6843
# ...

# %% [markdown]
# # #Question 2.b) Test RMSE pour le learning_rate = 1e-2.

# %%
print(" Les test RMSE du model est : ",cost_list_sgdT[-1])
# Out:
#  Les test RMSE du model est :  0.07288299865516307

# %%
plt.xlabel("epoch")
plt.ylabel("RMSE ")
plt.plot(epoch_list_sgdT,cost_list_sgdT, label = "Test RMSE")
plt.legend()

# %%
w_sgd1, b_sgd1, cost_list_sgd1, epoch_list_sgd1 = stochastic_gradient_descent(data_X, data_Y, 15000, learning_rate = 1e-4)
w_sgd1, b_sgd1,
# Out:
# 6921
# 8081
# 8188
# 8233
# 8241
# 8384
# 8792
# 8808
# 8929
# 9004
# 9166
# 9688
# 9847
# 10179
# 10286
# 10384
# 10431
# 10598
# 10610
# 10623
# 10856
# 11146
# 11204
# 11417
# 11459
# 11473
# 11625
# 11696
# 11698
# 11794
# 11932
# 11950
# 12129
# 12172
# 12376
# 12468
# 12493
# 12526
# 12725
# 12858
# 12868
# 12909
# 13027
# 13125
# 13163
# 13208
# 13301
# 13402
# 13413
# 13454
# 13480
# 13663
# 13806
# 13848
# 13898
# 13912
# 14000
# 14007
# 14034
# 14130
# 14167
# 14168
# 14342
# 14358
# 14381
# 14468
# 14480
# 14489
# 14504
# 14538
# 14583
# 14642
# 14678
# 14743
# 14754
# 14794
# 14834
# 14850
# 14906
# 14945
# 14967
# 14976
# (3.7631839634538147, 4.001616906055593)

# %%
Y_hat = w_sgd1*data_X + b_sgd1
# plt.plot(data_X, Y_hat, color='red') 
plt.plot(data_X,Y_hat, color='red') 
plt.plot(data_X, data_Y, "+b", label='Training data')
# plt.plot(data_V_X, data_V_Y, "+g", label='Validation')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Question 1.a) RMSE Train

# %%
print ("RMSE du train est :", cost_list_sgd1[-1])
# Out:
# RMSE du train est : 0.14970605018198704

# %% [markdown]
# # #Question 1.a) Plot Train RMSE VS epoch

# %%
plt.xlabel("epoch")
plt.ylabel("RMSE ")
plt.plot(epoch_list_sgd1,cost_list_sgd1, label = "Training RMSE")
plt.legend()

# %%
Y_hat = w_sgd*data_X + b_sgd
plt.plot(data_X, Y_hat, color='red') 
plt.plot(data_X,Y_hat, color='red') 
plt.plot(data_X, data_Y, "+b", label='Train')
plt.plot(data_V_X, data_V_Y, "+g", label='Validation')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
def fullbatch_gradient_descent(X, y_true, epochs, learning_rate ):
 
    w = 1
    b = 1
    total_samples = X.shape[0]
    
    cost_list = []
    epoch_list = []
#     index = np.arange(0,total_samples)
    cost_epoch = 0
    for j in range(epochs):

        y_predicted = X*w + b


        w_grad = -(2/total_samples) * (X.T.dot(y_true-y_predicted))
        b_grad = -(2/total_samples) * np.sum(y_true-y_predicted)

        w = w - learning_rate * w_grad
        b = b - learning_rate * b_grad
        
        cost = np.mean(np.square(y_true-y_predicted)) 
        cost_list.append(cost)
        epoch_list.append(j)

        if(j != 0 and np.abs(cost_list[-1] - cost_list[-2]) < 5e-6 ):
            print(j)
           
        
    return w, b, cost_list, epoch_list

# %%
w_sgdFP, b_sgdFP, cost_list_sgdFP, epoch_list_sgdFP = fullbatch_gradient_descent(data_V_X, data_V_Y, 15000, 1e-4)
w_sgdFP, b_sgdFP,
# Out:
# 13883
# 13884
# 13885
# 13886
# 13887
# 13888
# 13889
# 13890
# 13891
# 13892
# 13893
# 13894
# 13895
# 13896
# 13897
# 13898
# 13899
# 13900
# 13901
# 13902
# 13903
# 13904
# 13905
# 13906
# 13907
# 13908
# 13909
# 13910
# 13911
# 13912
# 13913
# 13914
# 13915
# 13916
# 13917
# 13918
# 13919
# 13920
# 13921
# 13922
# 13923
# 13924
# 13925
# 13926
# 13927
# 13928
# 13929
# 13930
# 13931
# 13932
# 13933
# 13934
# 13935
# 13936
# 13937
# 13938
# 13939
# 13940
# 13941
# 13942
# 13943
# 13944
# 13945
# 13946
# 13947
# 13948
# 13949
# 13950
# 13951
# 13952
# 13953
# 13954
# 13955
# 13956
# 13957
# 13958
# 13959
# 13960
# 13961
# 13962
# 13963
# 13964
# 13965
# 13966
# 13967
# 13968
# 13969
# 13970
# 13971
# 13972
# 13973
# 13974
# 13975
# 13976
# 13977
# 13978
# 13979
# 13980
# 13981
# 13982
# 13983
# 13984
# 13985
# 13986
# 13987
# 13988
# 13989
# 13990
# 13991
# 13992
# 13993
# 13994
# 13995
# 13996
# 13997
# 13998
# 13999
# 14000
# 14001
# 14002
# 14003
# 14004
# 14005
# 14006
# 14007
# ...

# %%
cost_list_sgdFP[-1]
# Out:
# 0.1278402289215272

# %% [markdown]
# # #Question 4) Plot Validation RMSE VS epoch FullBatch

# %%
plt.xlabel("epoch")
plt.ylabel("RMSE ")
plt.plot(epoch_list_sgdFP,cost_list_sgdFP, label = "Validation fullbatch")
plt.legend()

# %%
w_sgdFP1, b_sgdFP1, cost_list_sgdFP1, epoch_list_sgdFP1 = fullbatch_gradient_descent(data_X, data_Y, 15000, 1e-4)
w_sgdFP1, b_sgdFP1,
# Out:
# 13102
# 13103
# 13104
# 13105
# 13106
